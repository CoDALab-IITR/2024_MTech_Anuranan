# %%
# !pip install imdlib
import pandas as pd
import csv

# %%
import imdlib as imd
start_yr = 1960
end_yr = 2023
variable ='tmin'
data = imd.get_data(variable, start_yr, end_yr, fn_format = 'yearwise')
# Out:
# Downloading: mintemp for year 1960
# Downloading: mintemp for year 1961
# Downloading: mintemp for year 1962
# Downloading: mintemp for year 1963
# Downloading: mintemp for year 1964
# Downloading: mintemp for year 1965
# Downloading: mintemp for year 1966
# Downloading: mintemp for year 1967
# Downloading: mintemp for year 1968
# Downloading: mintemp for year 1969
# Downloading: mintemp for year 1970
# Downloading: mintemp for year 1971
# Downloading: mintemp for year 1972
# Downloading: mintemp for year 1973
# Downloading: mintemp for year 1974
# Downloading: mintemp for year 1975
# Downloading: mintemp for year 1976
# Downloading: mintemp for year 1977
# Downloading: mintemp for year 1978
# Downloading: mintemp for year 1979
# Downloading: mintemp for year 1980
# Downloading: mintemp for year 1981
# Downloading: mintemp for year 1982
# Downloading: mintemp for year 1983
# Downloading: mintemp for year 1984
# Downloading: mintemp for year 1985
# Downloading: mintemp for year 1986
# ...

# %%
import imdlib as imd

start_yr = 1960
end_yr = 2023
variable = 'tmin' # other options are ('tmin'/ 'tmax')
file_dir = (r'/content/tmin') #Path to save the files
data = imd.open_data(variable, start_yr, end_yr,'yearwise', file_dir)
data

# %%
ds = data.get_xarray()
print(ds)
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 23376, lat: 31, lon: 31)
# Coordinates:
#   * lat      (lat) float64 7.5 8.5 9.5 10.5 11.5 ... 33.5 34.5 35.5 36.5 37.5
#   * lon      (lon) float64 67.5 68.5 69.5 70.5 71.5 ... 93.5 94.5 95.5 96.5 97.5
#   * time     (time) datetime64[ns] 1960-01-01 1960-01-02 ... 2023-12-31
# Data variables:
#     tmin     (time, lat, lon) float64 99.9 99.9 99.9 99.9 ... 99.9 99.9 99.9
# Attributes:
#     Conventions:  CF-1.7
#     title:        IMD gridded data
#     source:       https://imdpune.gov.in/
#     history:      2024-03-04 11:25:22.865430 Python
#     references:
#     comment:
#     crs:          epsg:4326

# %%
ds = ds.where(ds['tmin'] != -999.) #Remove NaN values
ds['tmin'].mean('time').plot()

# %%
with open('/content/Raj_coordinates.csv', encoding='utf-8-sig') as file_obj:

    # Create reader object by passing the file
    # object to DictReader method
    reader_obj = csv.DictReader(file_obj)

    # Iterate over each row in the csv file
    # using reader object
    for row in reader_obj:
        print(row)
        loc=row['Loc']
        x=float(row['x'])
        y=float(row['y'])
        data.to_csv(loc+".csv", x, y, file_dir)
# Out:
# {'Loc': 'Ajmer', 'x': '26.27', 'y': '74.42'}
# {'Loc': 'Alwar', 'x': '27.34', 'y': '76.38'}
# {'Loc': 'Anupgarh', 'x': '29.07', 'y': '73.06'}
# {'Loc': 'Balotra', 'x': '25.49', 'y': '72.21'}
# {'Loc': 'Banswara', 'x': '23.3', 'y': '74.24'}
# {'Loc': 'Baran', 'x': '25.05', 'y': '76.33'}
# {'Loc': 'Barmer', 'x': '25.45', 'y': '71.25'}
# {'Loc': 'Bharatpur', 'x': '27.15', 'y': '77.3'}
# {'Loc': 'Bhilwara', 'x': '25.21', 'y': '74.4'}
# {'Loc': 'Bikaner', 'x': '28.01', 'y': '73.22'}
# {'Loc': 'Bundi', 'x': '25.27', 'y': '75.41'}
# {'Loc': 'Chittorgarh', 'x': '24.54', 'y': '74.42'}
# {'Loc': 'Churu', 'x': '28.19', 'y': '75.01'}
# {'Loc': 'Dausa', 'x': '26.89', 'y': '76.33'}
# {'Loc': 'Deeg', 'x': '27.47', 'y': '77.32'}
# {'Loc': 'Dholpur', 'x': '26.42', 'y': '77.53'}
# {'Loc': 'Didwana Kuchaman', 'x': '27.17', 'y': '74.25'}
# {'Loc': 'Dudu', 'x': '26.68', 'y': '75.23'}
# {'Loc': 'Dungarpur', 'x': '23.5', 'y': '73.5'}
# {'Loc': 'Gangapur', 'x': '26.29', 'y': '75.46'}
# ...

# %%
# !zip -r /content/tmin.zip /content/tmin
# Out:
#   adding: content/tmin/ (stored 0%)
#   adding: content/tmin/Hanumangarh_29.35_74.21.csv (deflated 74%)
#   adding: content/tmin/Gangapur_26.29_75.46.csv (deflated 75%)
#   adding: content/tmin/Bikaner_28.01_73.22.csv (deflated 75%)
#   adding: content/tmin/Dungarpur_23.50_73.50.csv (deflated 75%)
#   adding: content/tmin/2022.GRD (deflated 65%)
#   adding: content/tmin/2012.GRD (deflated 78%)
#   adding: content/tmin/1992.GRD (deflated 77%)
#   adding: content/tmin/Rajsamand_25.05_73.88.csv (deflated 75%)
#   adding: content/tmin/Dholpur_26.42_77.53.csv (deflated 75%)
#   adding: content/tmin/Jalore_25.52_72.58.csv (deflated 75%)
#   adding: content/tmin/1993.GRD (deflated 77%)
#   adding: content/tmin/Chittorgarh_24.54_74.42.csv (deflated 75%)
#   adding: content/tmin/2000.GRD (deflated 78%)
#   adding: content/tmin/Anupgarh_29.07_73.06.csv (deflated 74%)
#   adding: content/tmin/1971.GRD (deflated 77%)
#   adding: content/tmin/1995.GRD (deflated 78%)
# ...

# %%
from google.colab import files
files.download('/content/tmin.zip')
