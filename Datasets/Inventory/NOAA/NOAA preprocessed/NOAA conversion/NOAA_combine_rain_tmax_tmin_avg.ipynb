# %%
import pandas as pd
import csv

# %%
with open('/content/dailymonthly.csv', encoding='utf-8-sig') as file_obj:

    # Create reader object by passing the file
    # object to DictReader method
    reader_obj = csv.DictReader(file_obj)

    # Iterate over each row in the csv file
    # using reader object
    for row in reader_obj:
        print(row)
        daily=row['daily']
        monthly=row['monthly']
        df = pd.read_csv(daily+".csv")
        print(df.columns)
        df = df.drop('Date', axis='columns')
        total = df.groupby(['Year','Month'],as_index=False).mean()
        total.to_csv(monthly+'.csv')
# Out:
# {'daily': 'Ajmer', 'monthly': 'Ajmer'}
# Index(['Year', 'Month', 'Date', 'PCRP', 'tmin', 'tmax'], dtype='object')
# {'daily': 'Alwar', 'monthly': 'Alwar'}
# Index(['Year', 'Month', 'Date', 'PCRP', 'tmin', 'tmax'], dtype='object')
# {'daily': 'Anupgarh', 'monthly': 'Anupgarh'}
# Index(['Year', 'Month', 'Date', 'PCRP', 'tmin', 'tmax'], dtype='object')
# {'daily': 'Balotra', 'monthly': 'Balotra'}
# Index(['Year', 'Month', 'Date', 'tmax', 'tmin', 'PCRP'], dtype='object')
# {'daily': 'Banswara', 'monthly': 'Banswara'}
# Index(['Year', 'Month', 'Date', 'tmax', 'tmin', 'PCRP'], dtype='object')
# {'daily': 'Baran', 'monthly': 'Baran'}
# Index(['Year', 'Month', 'Date', 'tmax', 'tmin', 'PCRP'], dtype='object')
# {'daily': 'Barmer', 'monthly': 'Barmer'}
# Index(['Year', 'Month', 'Date', 'tmax', 'tmin', 'PCRP'], dtype='object')
# {'daily': 'Bharatpur', 'monthly': 'Bharatpur'}
# Index(['Year', 'Month', 'Date', 'tmax', 'tmin', 'PCRP'], dtype='object')
# ...

# %%
# !zip -r /content/NOAA_combine_rain_tmax_tmin_avg.zip /content
# Out:
#   adding: content/ (stored 0%)
#   adding: content/.config/ (stored 0%)
#   adding: content/.config/.last_opt_in_prompt.yaml (stored 0%)
#   adding: content/.config/configurations/ (stored 0%)
#   adding: content/.config/configurations/config_default (deflated 15%)
#   adding: content/.config/active_config (stored 0%)
#   adding: content/.config/logs/ (stored 0%)
#   adding: content/.config/logs/2024.03.19/ (stored 0%)
#   adding: content/.config/logs/2024.03.19/13.28.18.725105.log (deflated 56%)
#   adding: content/.config/logs/2024.03.19/13.28.05.366495.log (deflated 58%)
#   adding: content/.config/logs/2024.03.19/13.28.17.815361.log (deflated 57%)
#   adding: content/.config/logs/2024.03.19/13.27.55.194039.log (deflated 86%)
#   adding: content/.config/logs/2024.03.19/13.27.13.718539.log (deflated 91%)
#   adding: content/.config/logs/2024.03.19/13.27.42.999901.log (deflated 58%)
#   adding: content/.config/.last_survey_prompt.yaml (stored 0%)
# ...

# %%
from google.colab import files
files.download("/content/NOAA_combine_rain_tmax_tmin_avg.zip")
